# %%
# Create the employee table
spark.sql("""
CREATE TABLE employee (
    employee_id INT,
    dept_name STRING,
    joinedfrom DATE,
    release_date STRING
)
""")

# Insert 5 records
spark.sql("""
INSERT INTO employee VALUES
    (1, 'HR', '2022-01-15', '2023-12-31'),
    (2, 'Finance', '2021-05-10', 'NA'),
    (3, 'Engineering', '2020-09-01', '2024-06-30'),
    (4, 'Marketing', '2023-03-20', 'NA'),
    (5, 'Sales', '2022-11-05', '2025-07-15')
""")

# %%
# %sql
select current_catalog() , current_metastore() , current_database() , current_schema()
