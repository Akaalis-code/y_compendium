# %%
import os
from pyspark.sql import SparkSession
ss1=SparkSession.builder.appName('app_for_reading').getOrCreate()

# %%
ss1.stop()

# %%
ss1.read.format('csv')\
    .options(header = True,delimiter = ",", recursiveFileLookup = True )\
    .load("file:///home/yv05/Documents/y_claude_code_folder/y_spark_related/y_env_for_struct_stream/y_data_related_folder/y_output_folder/")\
    .show(truncate=False)
# Out:
# +-----+------------------------+------------------+-------------+------------------------+
# |empid|login_attempt_time      |success_or_failure|file_batch_id|Read_time               |
# +-----+------------------------+------------------+-------------+------------------------+
# |1001 |2026-08-15T09:12:33.000Z|success           |1            |2026-08-15T17:23:15.700Z|
# |1002 |2026-08-15T09:15:07.000Z|failure           |1            |2026-08-15T17:23:15.700Z|
# |1003 |2026-08-15T09:21:45.000Z|success           |1            |2026-08-15T17:23:15.700Z|
# |1004 |2026-08-15T09:30:19.000Z|failure           |1            |2026-08-15T17:23:15.700Z|
# +-----+------------------------+------------------+-------------+------------------------+
