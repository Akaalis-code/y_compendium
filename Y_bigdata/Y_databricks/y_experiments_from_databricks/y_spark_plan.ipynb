# %%
df_fresh = spark.read.csv("dbfs:/mnt/y_azure_raw/")

# %%
df_fresh.count()

# %%
df_fresh.filter(df_fresh["_c0"]<5).show()

# %%
df_fresh.show(5)

# %%
display(spark.sql("SELECT current_timestamp() AS server_time"))
